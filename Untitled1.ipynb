# %%
#!/usr/bin/env python
# coding: utf-8

# # Clustering

# In[1]:


import os, inspect, sys
sys.path.insert(0,'RGCPD')
sys.path.insert(0,'clustering')
sys.path.insert(0,'df_analysis/df_analysis')
import numpy as np
import matplotlib.pyplot as plt
user_dir = '/mnt/c/Users/lenna/Documents/Studie/2019-2020/Scriptie/RGCPD'

curr_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe()))) # script directory
main_dir = '/'.join(curr_dir.split('/')[:-1])
RGCPD_func = os.path.join(main_dir, 'RGCPD')
cluster_func = os.path.join(main_dir, 'clustering/')
df_ana_func =  os.path.join(main_dir, 'df_analysis/df_analysis/')
if cluster_func not in sys.path:
    sys.path.append(main_dir)
    sys.path.append(RGCPD_func)
    sys.path.append(cluster_func)
    sys.path.append(df_ana_func)


if sys.platform == 'linux':
    import matplotlib as mpl
    mpl.use('Agg')
    root_data = '/scistor/ivm/data_catalogue/reanalysis/ERA5'
else:
    root_data = '/Users/semvijverberg/surfdrive/ERA5'
    
path_outmain = user_dir+'/ERA5/clustered/output_RGCPD'
# In[2]:


import functions_pp
import clustering_spatial as cl
import plot_maps
import df_ana
from RGCPD import RGCPD

local_base_path = "/mnt/c/Users/lenna/Documents/Studie/2019-2020/Scriptie/RGCPD"
local_script_dir = os.path.join(local_base_path, "ERA5" )

list_of_name_path = [('fake', None),
                     ('t2mmmax', local_script_dir + '/mx2t_US_1979-2020_1_12_daily_1.0deg.nc')]
rg = RGCPD(list_of_name_path=list_of_name_path,
           path_outmain=path_outmain)



# In[3]:


rg.pp_precursors()


# In[ ]:


rg.list_precur_pp

var_filename = rg.list_precur_pp[0][1]

#%%
import make_country_mask
selbox = (225, 300, 30, 70)
xarray, Country = make_country_mask.create_mask(var_filename, kwrgs_load={'selbox':selbox}, level='Countries')
mask_US_CA = np.logical_or(xarray.values == Country.US, xarray.values==Country.CA)
xr_mask = xarray.where(make_country_mask.binary_erosion(mask_US_CA))
xr_mask.values[make_country_mask.binary_erosion(mask_US_CA)]  = 1
xr_mask = cl.mask_latlon(xr_mask, latmax=63, lonmax=270)
plot_maps.plot_labels(xr_mask)



# In[9]:
# =============================================================================
# Clustering co-occurence of anomalies
# =============================================================================
tfreq = [5, 10, 15, 30]
n_clusters = [2,3,4,5,6,7,8]
from time import time
t0 = time()
xrclustered, results = cl.dendogram_clustering(var_filename, mask=xr_mask,
                                               kwrgs_load={'tfreq':tfreq,
                                                           'seldates':('06-15', '08-31'),
                                                           'selbox':selbox},
                                               kwrgs_clust={'q':66,
                                                            'n_clusters':n_clusters,
                                                            'affinity':'jaccard',
                                                            'linkage':'average'})
fig = plot_maps.plot_labels(xrclustered, wspace=.05, hspace=-.2, cbar_vert=.08,
                      row_dim='tfreq', col_dim='n_clusters')
f_name = 'clustering_dendogram_{}'.format(xrclustered.attrs['hash']) + '.pdf'
path_fig = os.path.join(rg.path_outmain, f_name)
plt.savefig(path_fig,
            bbox_inches='tight') # dpi auto 600
print(f'{round(time()-t0, 2)}')

#%%
# =============================================================================
# Clustering correlation Hierarchical Agglomerative Clustering
# =============================================================================
from time import time
t0 = time()
xrclustered, results = cl.correlation_clustering(var_filename, mask=xr_mask,
                                               kwrgs_load={'tfreq':tfreq,
                                                           'seldates':('06-01', '08-31'),
                                                           'selbox':selbox},
                                               clustermethodkey='AgglomerativeClustering',
                                               kwrgs_clust={'n_clusters':n_clusters,
                                                            'affinity':'correlation',
                                                            'linkage':'average'})

plot_maps.plot_labels(xrclustered,  wspace=.05, hspace=-.2, cbar_vert=.08,
                            row_dim='tfreq', col_dim='n_clusters')

f_name = 'clustering_correlation_{}'.format(xrclustered.attrs['hash']) + '.pdf'
path_fig = os.path.join(rg.path_outmain, f_name)
plt.savefig(path_fig,
            bbox_inches='tight') # dpi auto 600
print(f'{round(time()-t0, 2)}')

#%%
# # =============================================================================
# # Clustering OPTICS
# # =============================================================================
# var_filename = rg.list_precur_pp[0][1]
# # mask = [155.0, 230.0, 40.0, 45.0]
# # mask = None
# # mask = '/Users/semvijverberg/surfdrive/Data_era5/input_raw/mask_North_America_0.25deg.nc'
# from time import time ; t0 = time()
# xrclustered, results = cl.correlation_clustering(var_filename, mask=xr_mask,
#                                                kwrgs_load={'tfreq':10,
#                                                            'seldates':('06-01', '08-31'),
#                                                            'selbox':selbox},
#                                                clustermethodkey='OPTICS',
#                                                kwrgs_clust={#'eps':.05,
#                                                             'min_samples':5,
#                                                             'metric':'minkowski',
#                                                              'n_jobs':-1})

# plot_maps.plot_labels(xrclustered)
# print(f'{round(time()-t0, 2)}')


#%%
for t in tfreq:
    for c in n_clusters:    
        # t = 30 ; c=8
        ds = cl.spatial_mean_clusters(var_filename,
                                  xrclustered.sel(tfreq=t, n_clusters=c),
                                  selbox=selbox)


        df_clust = functions_pp.xrts_to_df(ds['ts'])
    
        fig = df_ana.loop_df(df_clust, function=df_ana.plot_ac, sharex=False, kwrgs={'AUC_cutoff':(14,30)})
        fig.suptitle('tfreq: {}, n_clusters: {}'.format(t, c), x=.5, y=.97)
#%%
t = 15 ; c = 5        
ds = cl.spatial_mean_clusters(var_filename,
                         xrclustered.sel(tfreq=t, n_clusters=c),
                         selbox=selbox)
cl.store_netcdf(ds, filepath=rg.path_outmain, append_hash='dendo_'+xrclustered.attrs['hash'])

#%%
# # =============================================================================
# # regrid for quicker validation
# # =============================================================================
# to_grid=1
# xr_regrid = cl.regrid_array(var_filename, to_grid=to_grid)
# cl.store_netcdf(xr_regrid, filepath=None, append_hash=f'{to_grid}d')

# xr_rg_clust = cl.regrid_array(xrclustered, to_grid=to_grid, periodic=False)
# ds = cl.spatial_mean_clusters(var_filename,
#                               xr_rg_clust)
# cl.store_netcdf(ds, filepath=None, append_hash=f'{to_grid}d_' + xrclustered.attrs['hash'])



# In[ ]:
# Out:
# /home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 563, in start
#     self.io_loop.start()
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2852, in run_cell
#     self.events.trigger('post_run_cell', result)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/IPython/core/events.py", line 88, in trigger
#     func(*args, **kwargs)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 164, in configure_once
#     activate_matplotlib(backend)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/IPython/core/pylabtools.py", line 314, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/matplotlib/__init__.py", line 1422, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "/home/lennart/miniconda3/envs/RGCPD/lib/python3.7/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
# ['time', 'longitude', 'latitude', 'mx2t']
#
# Performing the post-processing t2mmmax
# ['time', 'longitude', 'latitude', 'mx2t']
# Performing 25 day rolling mean with gaussian window (std=12.5) to get better interannual statistics
# using absolute anomalies w.r.t. climatology of smoothed concurrent day accross years
# Detrending based on interannual trend of 25 day smoothened day of year
#
# using absolute anomalies w.r.t. climatology of smoothed concurrent day accross years
#
# Processing 100%
# writing ncdf file to:
# /mnt/c/Users/lenna/Documents/Studie/2019-2020/Scriptie/RGCPD/ERA5/preprocessed/mx2t_US_1979-2020_1jan_31dec_daily_1.0deg.nc
# ['time', 'longitude', 'latitude', 'mask', 'mx2t']
# Creating Country Mask:    3116/   3116 (100.0%)
# Plotting Corr maps country_mask, split 0, lag 0
#
# ['time', 'longitude', 'latitude', 'mask', 'mx2t']
# clustering tfreq: 5, n_clusters: 2 ['time', 'longitude', 'latitude', 'mask', 'mx2t']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-9e72f4b300e2> in <module>
#      94                                                             'n_clusters':n_clusters,
#      95                                                             'affinity':'jaccard',
# ---> 96                                                             'linkage':'average'})
#      97 fig = plot_maps.plot_labels(xrclustered, wspace=.05, hspace=-.2, cbar_vert=.08,
#      98                       row_dim='tfreq', col_dim='n_clusters')
#
# /mnt/c/Users/lenna/Documents/Studie/2019-2020/Scriptie/RGCPD/clustering/clustering_spatial.py in dendogram_clustering(var_filename, mask, kwrgs_load, clustermethodkey, kwrgs_clust)
#     164                 print(f"\rclustering {new_coords[0]}: {v1}, {new_coords[1]}: {v2} ", end="")
#     165                 if len(kwrgs_loop_load) != 0: # some param has been adjusted
# --> 166                     xarray_ts = functions_pp.import_ds_timemeanbins(var_filename, **kwrgs_l)
#     167                     if type(q) is int:
#     168                             xarray = binary_occurences_quantile(xarray_ts, q=q)
#
# /mnt/c/Users/lenna/Documents/Studie/2019-2020/Scriptie/RGCPD/RGCPD/functions_pp.py in import_ds_timemeanbins(filepath, tfreq, start_end_date, start_end_year, selbox, loadleap, to_xarr, seldates, format_lon)
#     285     ds = core_pp.import_ds_lazy(filepath, loadleap=loadleap,
#     286                                 seldates=seldates, selbox=selbox,
# --> 287                                 format_lon=format_lon)
#     288
#     289     to_freq = tfreq
#
# /mnt/c/Users/lenna/Documents/Studie/2019-2020/Scriptie/RGCPD/RGCPD/core_pp.py in import_ds_lazy(filename, loadleap, seldates, selbox, format_lon, var)
#     106                          start_end_year=None, lpyr=loadleap
#     107                          )
# --> 108             ds = ds.sel(time=pddates)
#     109         else:
#     110             ds = ds.sel(time=seldates)
#
# ~/miniconda3/envs/RGCPD/lib/python3.7/site-packages/xarray/core/dataarray.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1031             method=method,
#    1032             tolerance=tolerance,
# -> 1033             **indexers_kwargs
#    1034         )
#    1035         return self._from_temp_dataset(ds)
#
# ~/miniconda3/envs/RGCPD/lib/python3.7/site-packages/xarray/core/dataset.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2004         indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
#    2005         pos_indexers, new_indexes = remap_label_indexers(
# -> 2006             self, indexers=indexers, method=method, tolerance=tolerance
#    2007         )
#    2008         result = self.isel(indexers=pos_indexers, drop=drop)
#
# ~/miniconda3/envs/RGCPD/lib/python3.7/site-packages/xarray/core/coordinates.py in remap_label_indexers(obj, indexers, method, tolerance, **indexers_kwargs)
#     378
#     379     pos_indexers, new_indexes = indexing.remap_label_indexers(
# --> 380         obj, v_indexers, method=method, tolerance=tolerance
#     381     )
#     382     # attach indexer's coordinate to pos_indexers
#
# ~/miniconda3/envs/RGCPD/lib/python3.7/site-packages/xarray/core/indexing.py in remap_label_indexers(data_obj, indexers, method, tolerance)
#     273             coords_dtype = data_obj.coords[dim].dtype
#     274             label = maybe_cast_to_coords_dtype(label, coords_dtype)
# --> 275             idxr, new_idx = convert_label_indexer(index, label, dim, method, tolerance)
#     276             pos_indexers[dim] = idxr
#     277             if new_idx is not None:
#
# ~/miniconda3/envs/RGCPD/lib/python3.7/site-packages/xarray/core/indexing.py in convert_label_indexer(index, label, index_name, method, tolerance)
#     205             indexer = get_indexer_nd(index, label, method, tolerance)
#     206             if np.any(indexer < 0):
# --> 207                 raise KeyError("not all values found in index %r" % index_name)
#     208     return indexer, new_index
#     209
#
# KeyError: "not all values found in index 'time'"
